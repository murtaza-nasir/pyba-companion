# %%
# Setup. Run this cell once per session. On Google Colab it fetches the
# course materials (the pyba package and the data) so the next cell works.
import sys
if "google.colab" in sys.modules:
    # !test -d pyba-companion || git clone --quiet --depth 1 https://github.com/murtaza-nasir/pyba-companion.git
    sys.path.insert(0, "pyba-companion")   # makes `import pyba` (DATA_DIR) work

# %%
# Your first analysis: load Prairie Wholesale's order table and count the orders.
# If this cell runs and prints a number, your machine is ready for the course.
import pandas as pd
from pyba import DATA_DIR

orders = pd.read_csv(DATA_DIR / "pw_orders.csv", parse_dates=["order_date"])
print(f"{orders['order_id'].nunique():,} orders, {len(orders):,} order lines. You're ready.")
